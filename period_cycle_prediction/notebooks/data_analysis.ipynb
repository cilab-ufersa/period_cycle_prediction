# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils.utils import generate_synthetic_data, generate_final_features, split_dataset
import warnings 
warnings.filterwarnings("ignore")

# %%
# generate the synthetic data
total_regular_cycle_data = generate_synthetic_data(duration_cycle=5, start_day=1, year=2020, start_month_index=1, number_of_cycle=24, period_duration=30, cycle_interval=[5,5], period_interval=[28, 30])
regular_cycle_data = generate_synthetic_data(duration_cycle=5, start_day=1, year=2020, start_month_index=1, number_of_cycle=24, period_duration=30, cycle_interval=[5, 6], period_interval=[28, 35])
irregular_cycle_data = generate_synthetic_data(duration_cycle=5, start_day=1, year=2020, start_month_index=1, number_of_cycle=24, period_duration=30, cycle_interval=[4, 8], period_interval=[28, 49])

# %%
# load the data
total_regular_cycle_data = pd.read_csv('dataset\\total_regular_cycle_data.csv')
regular_cycle_data = pd.read_csv('dataset\\regular_cycle_data.csv')
irregular_cycle_data = pd.read_csv('dataset\irregular_cycle_data.csv')

# %%
# generate the final features
features_total_regular_cycle_data, labels_total_regular_cycle_data = generate_final_features(total_regular_cycle_data)
features_regular_cycle_data, labels_regular_cycle_data = generate_final_features(regular_cycle_data)
features_irregular_cycle_data, labels_irregular_cycle_data = generate_final_features(irregular_cycle_data)

# %%
# slice the data with split_dataset function
input_train_total_regular_cycle, input_test_total_regular_cycle, output_train_total_regular_cycle, output_test_total_regular_cycle = split_dataset(features_total_regular_cycle_data, labels_total_regular_cycle_data)
input_train_regular_cycle, input_test_regular_cycle, output_train_regular_cycle, output_test_regular_cycle = split_dataset(features_regular_cycle_data, labels_regular_cycle_data)
input_train_irregular_cycle, input_test_irregular_cycle, output_train_irregular_cycle, output_test_irregular_cycle = split_dataset(features_irregular_cycle_data, labels_irregular_cycle_data)

# %%
#plot the distribution of the data with distplot
sns.distplot(tuple(input_train_total_regular_cycle[:,0]), hist=True, kde=True, kde_kws={'color': 'red', 'shade': False, 'linewidth': 3}, label='Total Regular Cycle')
plt.title('Case 1')
# change font size of the labels 
plt.rcParams.update({'font.size': 20})
plt.xlabel('Menstrual Cycle Duration (Days)')
plt.ylabel('Density')
# save the plot in eps format
fig = plt.gcf()
fig.savefig('totalregularcycle.eps', dpi=300, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#plot the distribution of the data with distplot
sns.distplot(tuple(input_train_total_regular_cycle[:,1]), hist=True, kde=True, kde_kws={'color': 'red', 'shade': False, 'linewidth': 3}, label='Total Regular Cycle')
plt.title('Case 1')
plt.xlabel('Period days')
plt.ylabel('Density')
fig = plt.gcf()
fig.savefig('case1.eps', dpi=300, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
sns.distplot(tuple(input_train_regular_cycle[:,0]), hist=True, kde=True, kde_kws={'color': 'red', 'shade': False, 'linewidth': 3}, label='Total Regular Cycle')
plt.title('Case 2')
plt.xlabel('Menstrual Cycle Duration (Days)')
plt.ylabel('Density')
fig = plt.gcf()
fig.savefig('regularcycle.eps', dpi=300, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
sns.distplot(tuple(input_train_regular_cycle[:,1]), hist=True, kde=True, kde_kws={'color': 'red', 'shade': False, 'linewidth': 3}, label='Total Regular Cycle')
plt.title('Case 2')
plt.xlabel('Period days')
plt.ylabel('Density')
fig = plt.gcf()
fig.savefig('case2.eps', dpi=300, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
sns.distplot(tuple(input_train_irregular_cycle[:,0]), hist=True, kde=True, kde_kws={'color': 'red', 'shade': False, 'linewidth': 3}, label='Total Regular Cycle')
plt.title('Case 3')
plt.xlabel('Menstrual Cycle Duration (Days)')
plt.ylabel('Density')
fig = plt.gcf()
fig.savefig('irregularcycle.eps', dpi=300, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
sns.distplot(tuple(input_train_irregular_cycle[:,1]), hist=True, kde=True, kde_kws={'color': 'red', 'shade': False, 'linewidth': 3}, label='Total Regular Cycle')
plt.title('Case 3')
plt.xlabel('Period days')
plt.ylabel('Density')
fig = plt.gcf()
fig.savefig('case3.eps', dpi=300, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
sns.boxplot(tuple(input_train_total_regular_cycle[:,0]))
plt.title('Case 1')
plt.ylabel('Menstrual Cycle Duration (Days)')
fig = plt.gcf()
fig.savefig('boxplottotalregularcycle.eps', dpi=300, bbox_inches='tight')

# %%
sns.boxplot(tuple(input_train_total_regular_cycle[:,1]))
plt.rcParams.update({'font.size': 20})
plt.title('Case 1')
plt.ylabel('Period days')
fig = plt.gcf()
fig.savefig('boxploCase1.eps', dpi=300, bbox_inches='tight')

# %%
sns.boxplot(tuple(input_train_regular_cycle[:,0]))
plt.title('Case 2')
plt.ylabel('Menstrual Cycle Duration (Days)')
fig = plt.gcf()
fig.savefig('boxplotregularcycle.eps', dpi=300, bbox_inches='tight')

# %%
sns.boxplot(tuple(input_train_regular_cycle[:,1]))
plt.title('Case 2')
plt.ylabel('Period days')
fig = plt.gcf()
fig.savefig('boxplotCase2.eps', dpi=300, bbox_inches='tight')

# %%
sns.boxplot(tuple(input_train_irregular_cycle[:,0]))
plt.title('Case 3')
plt.ylabel('Menstrual Cycle Duration (Days)')
fig = plt.gcf()
fig.savefig('boxplotirregularcycle.eps', dpi=300, bbox_inches='tight')

# %%
sns.boxplot(tuple(input_train_irregular_cycle[:,1]))
plt.title('Case  3')
plt.ylabel('Period days')
fig = plt.gcf()
fig.savefig('boxplotCase3.eps', dpi=300, bbox_inches='tight')
