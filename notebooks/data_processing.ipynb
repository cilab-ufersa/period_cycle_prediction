# %%
# bibliotecas necenecessárias 
import pandas as pd                       
import numpy as np

# %%
# leitura do dataset 
df = pd.read_csv('..\dataset\cycle_data.csv')
df.head()
# Out:
#   ClientID  CycleNumber  Group  CycleWithPeakorNot  ReproductiveCategory  \
# 0  nfp8122            1      0                   1                     0
# 1  nfp8122            2      0                   1                     0
# 2  nfp8122            3      0                   1                     0
# 3  nfp8122            4      0                   1                     0
# 4  nfp8122            5      0                   1                     0
#
#    LengthofCycle MeanCycleLength EstimatedDayofOvulation LengthofLutealPhase  \
# 0             29           27.33                      17                  12
# 1             27                                      15                  12
# 2             29                                      15                  14
# 3             27                                      15                  12
# 4             28                                      16                  12
#
# ...

# %%
from period_cycle_prediction.utils import generate_synthetic_data

df = generate_synthetic_data(duration_cycle=5, start_day=25, year=2021, start_month_index=1, number_of_cycle = 5, period_duration = 30)
